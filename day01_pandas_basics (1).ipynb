# %%
import pandas as pd

#Series(1D Data)
a=pd.Series([10,20,30])

#DataFrame(2D Data)
b=pd.DataFrame({"Name":["Jay","Smith","John","Rachel","Maya"],
                "Age":[24,21,28,22,30],
               "Designation":["Software Developer","Teacher","Data Analyst","ML Engineer","Product Manager"]})
print(a)
print(b)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
#      Name  Age         Designation
# 0     Jay   24  Software Developer
# 1   Smith   21             Teacher
# 2    John   28        Data Analyst
# 3  Rachel   22         ML Engineer
# 4    Maya   30     Product Manager

# %%
b.head(2)
# Out:
#     Name  Age         Designation
# 0    Jay   24  Software Developer
# 1  Smith   21             Teacher

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5 non-null      object
#  1   Age          5 non-null      int64
#  2   Designation  5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
b.shape
# Out:
# (5, 3)

# %%
b.tail(2)
# Out:
#      Name  Age      Designation
# 3  Rachel   22      ML Engineer
# 4    Maya   30  Product Manager

# %%
b.describe()
# Out:
#              Age
# count   5.000000
# mean   25.000000
# std     3.872983
# min    21.000000
# 25%    22.000000
# 50%    24.000000
# 75%    28.000000
# max    30.000000

# %%
b["Age"]
# Out:
# 0    24
# 1    21
# 2    28
# 3    22
# 4    30
# Name: Age, dtype: int64

# %%
b[["Age","Designation"]]
# Out:
#    Age         Designation
# 0   24  Software Developer
# 1   21             Teacher
# 2   28        Data Analyst
# 3   22         ML Engineer
# 4   30     Product Manager

# %%
b[b["Age"]>25]
# Out:
#    Name  Age      Designation
# 2  John   28     Data Analyst
# 4  Maya   30  Product Manager

# %%
b.isnull().sum()
# Out:
# Name           0
# Age            0
# Designation    0
# dtype: int64

# %%
b["Promotion"]=b["Age"]>25

# %%
b
# Out:
#      Name  Age         Designation  Promotion
# 0     Jay   24  Software Developer      False
# 1   Smith   21             Teacher      False
# 2    John   28        Data Analyst       True
# 3  Rachel   22         ML Engineer      False
# 4    Maya   30     Product Manager       True

# %%
b.sort_values("Age", ascending=False)
# Out:
#      Name  Age         Designation  Promotion
# 4    Maya   30     Product Manager       True
# 2    John   28        Data Analyst       True
# 0     Jay   24  Software Developer      False
# 3  Rachel   22         ML Engineer      False
# 1   Smith   21             Teacher      False

# %%
b.rename(columns={"Designation": "Role"})
# Out:
#      Name  Age                Role  Promotion
# 0     Jay   24  Software Developer      False
# 1   Smith   21             Teacher      False
# 2    John   28        Data Analyst       True
# 3  Rachel   22         ML Engineer      False
# 4    Maya   30     Product Manager       True
