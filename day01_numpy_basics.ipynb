# %%
l=[1,2,3]
print(l)
# Out:
# [1, 2, 3]

# %%
l[0]=10

# %%
print(l)
# Out:
# [10, 2, 3]

# %%
t=(1,2,3)
print(t)
# Out:
# (1, 2, 3)

# %%
t[0]=10
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t[0]=10
#       2 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#List Comprehension
squares=[i*i for i in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
def mean(y):
    return sum(y)/len(y)

print(mean(l))
# Out:
# 5.0

# %%
#Lambda Functions
x=lambda z:z+10
print(x(10))
# Out:
# 20

# %%
cubes=list(map(lambda x:x*x*x,[1,2,3]))
print(cubes)
# Out:
# [1, 8, 27]

# %%
#Used in Data Cleaning
filtered=list(filter(lambda x:x%5==0,[2,5,10,20,24]))
print(filtered)
# Out:
# [5, 10, 20]

# %%
import numpy as np
a=np.array([2,3,4])
print(a)
# Out:
# [2 3 4]

# %%
a.shape     #In ML wrong shape=Wrong model
# Out:
# (3,)

# %%
a.dtype      #In ML wrong dtype=performance loss
# Out:
# dtype('int64')

# %%
a[0:2]
# Out:
# array([2, 3])

# %%
#2D Array
m=np.array([[1,2,3,4,5],[2,4,6,8,10]])
print(m)
# Out:
# [[ 1  2  3  4  5]
#  [ 2  4  6  8 10]]

# %%
m[0,3]
# Out:
# np.int64(4)

# %%
#Broadcasting
a+10
# Out:
# array([12, 13, 14])

# %%
a=a*3
print(a)
# Out:
# [ 6  9 12]

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])
A@B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
A.mean()
# Out:
# np.float64(2.5)

# %%
A.mean(axis=0)  #Vertical
# Out:
# array([2., 3.])

# %%
A.mean(axis=1) #Horizontal
# Out:
# array([1.5, 3.5])

# %%
A.std()
# Out:
# np.float64(1.118033988749895)
